# %%
from googletrans import Translator
import os
import re
from shutil import copyfile
import sys

# Babel -> Google dictionary


translator      = Translator()
translation_dir = "/home/zetdg/Devasoft/devablog/app/translations"

lang_dir = sys.argv;
#lang_dir = os.listdir(translation_dir)

if len(lang_dir) == 1:
    lang_dir = os.listdir(translation_dir)
else:
    lang_dir = lang_dir[1:]


for f,lang_acronyms in enumerate(lang_dir):
    message_file = os.path.join(translation_dir,lang_acronyms,'LC_MESSAGES/messages.po')


    print(str(f) + ' of ' + str(len(lang_dir)),lang_acronyms,message_file)
    
    if not os.path.isfile(message_file):
        print("\tFile {} doesn't exist".format(message_file))
        continue

    mfile    = open(message_file,"r")
    
    
    id_source        = []
    id_translate     = []
    translated_lines = []
    
    all_lines = mfile.readlines();
    mfile.close()
    translated_lines = all_lines
    
    for l,line in enumerate(all_lines):
        split_line = line.split(" ")
        
        if split_line[0]=='msgid':
            id_source.append(l)
            
        if split_line[0]=='msgstr':
            id_translate.append(l)
    
    
    cont = 0;
    for s,t in zip(id_source,id_translate):
        cont = cont + 1;
        
        source_text = re.findall('(\".+?\")',all_lines[s])
        translate_text = re.findall('(\".+?\")',all_lines[t])
        
        if not len(translate_text)==0:
            continue
        
        if len(source_text):
            print(str(cont) + ' of ' + str(len(id_translate)))
            source_text = source_text[0]
            source_text = source_text[1:-1]
            
            
            Splitted    = re.split("(\%\(.+?\)s)",source_text)
            #TagName     = re.findall("(\%\(.+?\)s)",source_text)
            Dummy       = re.sub("(\%\(.+?\)s)","_@@_",source_text)

            Translated          = translator.translate(Dummy, dest=lang_acronyms)
            Translated          = Translated.text

            SplittedTranslation = re.split("(_\s*@@\s*_)",Translated)

            translated_text = []
            for c,chunk in enumerate(Splitted):
                if c % 2:
                    translated_text.append(Splitted[c])
                else:
                    translated_text.append(SplittedTranslation[c])

            translated_text     = ''.join(translated_text)
            translated_lines[t] = 'msgstr "'+ translated_text +'"\n'

            #print(source_text, '->', translated_lines[t], end='')
            print('\t'+source_text, '->', translated_text)

            

    message_file
    copyfile(message_file, message_file+'.bkp')
    os.remove(message_file)
    
    mfile = open(message_file,"w")
    for line in translated_lines:
        mfile.write("%s" % line)
    mfile.close()
# Out:
# 0 of 5 ja /home/zetdg/Devasoft/devablog/app/translations/ja/LC_MESSAGES/messages.po
#
# Now Translating...
# 1 of 55
# 2 of 55
# 3 of 55
# 4 of 55
# 5 of 55
# 6 of 55
# 7 of 55
# 8 of 55
# 9 of 55
# 10 of 55
# 11 of 55
# 12 of 55
# 13 of 55
# 14 of 55
# 15 of 55
# 16 of 55
# 17 of 55
# 18 of 55
# 19 of 55
# 20 of 55
# 21 of 55
# 22 of 55
# 23 of 55
# 24 of 55
# 25 of 55
# 26 of 55
# 27 of 55
# 28 of 55
# 29 of 55
# 30 of 55
# 31 of 55
# 32 of 55
# 33 of 55
# 34 of 55
# 35 of 55
# 36 of 55
# 37 of 55
# 38 of 55
# 39 of 55
# 40 of 55
# 41 of 55
# 42 of 55
# 43 of 55
# 44 of 55
# 45 of 55
# 46 of 55
# 47 of 55
# 48 of 55
# 49 of 55
# 50 of 55
# 51 of 55
# 52 of 55
# 53 of 55
# 54 of 55
# 55 of 55

# %%
from googletrans import Translator
import os
import re
from shutil import copyfile
import sys

# Babel -> Google dictionary


translator      = Translator()
translation_dir = "/home/zetdg/Devasoft/devablog/app/translations"

lang_dir = sys.argv;
#lang_dir = os.listdir(translation_dir)

if len(lang_dir) == 1:
    lang_dir = os.listdir(translation_dir)
else:
    lang_dir = lang_dir[1:]


for f,lang_acronyms in enumerate(lang_dir):
    message_file = os.path.join(translation_dir,lang_acronyms,'LC_MESSAGES/messages.po')


    print(str(f) + ' of ' + str(len(lang_dir)),lang_acronyms,message_file)
    
    if not os.path.isfile(message_file):
        print("\tFile {} doesn't exist".format(message_file))
        continue

    mfile    = open(message_file,"r")
    
    
    id_source        = []
    id_translate     = []
    translated_lines = []
    
    all_lines = mfile.readlines();
    mfile.close()
    translated_lines = all_lines
    
    for l,line in enumerate(all_lines):
        split_line = line.split(" ")
        
        if split_line[0]=='msgid':
            id_source.append(l)
            
        if split_line[0]=='msgstr':
            id_translate.append(l)
    
    
    cont = 0;
    for s,t in zip(id_source,id_translate):
        cont = cont + 1;
        
        source_text = re.findall('(\".+?\")',all_lines[s])
        translate_text = re.findall('(\".+?\")',all_lines[t])
        
        if not len(translate_text)==0:
            continue
        
        if len(source_text):
            print(str(cont) + ' of ' + str(len(id_translate)))
            source_text = source_text[0]
            source_text = source_text[1:-1]
            
            
            Splitted    = re.split("(\%\(.+?\)s)",source_text)
            #TagName     = re.findall("(\%\(.+?\)s)",source_text)
            Dummy       = re.sub("(\%\(.+?\)s)","_@@_",source_text)

            Translated          = translator.translate(Dummy, dest=lang_acronyms)
            Translated          = Translated.text

            SplittedTranslation = re.split("(_\s*@@\s*_)",Translated)

            translated_text = []
            for c,chunk in enumerate(Splitted):
                if c % 2:
                    translated_text.append(Splitted[c])
                else:
                    translated_text.append(SplittedTranslation[c])

            translated_text     = ''.join(translated_text)
            translated_lines[t] = 'msgstr "'+ translated_text +'"\n'

            #print(source_text, '->', translated_lines[t], end='')
            print('\t'+source_text, '->', translated_text)

            

    message_file
    copyfile(message_file, message_file+'.bkp')
    os.remove(message_file)
    
    mfile = open(message_file,"w")
    for line in translated_lines:
        mfile.write("%s" % line)
    mfile.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f3c58ec47c30> in <module>()
# ----> 1 all_lines[t]
#
# NameError: name 'all_lines' is not defined

# %%
from googletrans import Translator
import os
import re
from shutil import copyfile
import sys

translator      = Translator()
translation_dir = "/home/zetdg/Devasoft/devablog/app/translations"

"""
lang_dir = sys.argv;
lang_dir = os.listdir(translation_dir)

if len(lang_dir) == 1:
    lang_dir = os.listdir(translation_dir)
else:
    lang_dir = lang_dir[1:]
"""

lang_dir = ["fr"]

for f,lang_acronyms in enumerate(lang_dir):
    message_file = os.path.join(translation_dir,lang_acronyms,'LC_MESSAGES/messages.po')


    print(str(f) + ' of ' + str(len(lang_dir)),lang_acronyms,message_file)
    
    if not os.path.isfile(message_file):
        print("\tFile {} doesn't exist".format(message_file))
        continue

    mfile    = open(message_file,"r")
    
    
    id_source        = []
    id_translate     = []
    translated_lines = []
    
    all_lines = mfile.readlines();
    mfile.close()
    translated_lines = all_lines
    
    for l,line in enumerate(all_lines):
        split_line = line.split(" ")
        
        if split_line[0]=='msgid':
            id_source.append(l)
            
        if split_line[0]=='msgstr':
            id_translate.append(l)
    
    print('\nNow Translating...')
    cont = 0;
    for s,t in zip(id_source,id_translate):
        cont = cont + 1;
        print(str(cont) + ' of ' + str(len(id_translate)))
        source_text = re.findall('(\".+?\")',all_lines[s])
        translate_text = re.findall('(\".+?\")',all_lines[t])
        
        if not len(translate_text)==0:
            continue
            
        if len(source_text):
            source_text = source_text[0]
            source_text = source_text[1:-1]
            
            
            Splitted    = re.split("(\%\(.+?\)s)",source_text)
            #TagName     = re.findall("(\%\(.+?\)s)",source_text)
            Dummy       = re.sub("(\%\(.+?\)s)","_@@_",source_text)

            Translated          = translator.translate(Dummy, dest=lang_acronyms)
            Translated          = Translated.text

            SplittedTranslation = re.split("(_\s*@@\s*_)",Translated)

            translated_text = []
            for c,chunk in enumerate(Splitted):
                if c % 2:
                    translated_text.append(Splitted[c])
                else:
                    translated_text.append(SplittedTranslation[c])

            translated_text     = ''.join(translated_text)
            translated_lines[t] = 'msgstr "'+ translated_text +'"\n'

            #print(source_text, '->', translated_lines[t], end='')
            print(source_text, '->', translated_text)

            
    return 0
"""
    message_file
    copyfile(message_file, message_file+'.bkp')
    os.remove(message_file)
    
    mfile = open(message_file,"w")
    for line in translated_lines:
        mfile.write("%s" % line)
    mfile.close()
"""
# Out:
# 0 of 5 ja /home/zetdg/Devasoft/devablog/app/translations/ja/LC_MESSAGES/messages.po
#
# Now Translating...
# 1 of 55
# 2 of 55
# Please log in to access this page. -> このページにアクセスするには、ログインしてください。
# 3 of 55
# Username -> ユーザー名
# 4 of 55
# Password -> パスワード
# 5 of 55
# Remember Me -> 私を覚えてますか
# 6 of 55
# Sign In -> サインイン
# 7 of 55
# Email -> Eメール
# 8 of 55
# Repeat Password -> パスワードを再度入力してください
# 9 of 55
# Register -> 登録
# 10 of 55
# Please use a different username. -> 別のユーザー名を使用してください。
# 11 of 55
# Please use a different email address. -> 別のメールアドレスを使用してください。
# 12 of 55
# Request Password Reset -> リクエストパスワードのリセット
# 13 of 55
# About me -> 私について
# 14 of 55
# Submit -> 提出する
# 15 of 55
# The original name is %(username)s. -> 元の名前は%(username)sです。
# 16 of 55
# Choose another name, %(username)s is in the database (%(about_me)s). -> 別の名前を選択してください。%(username)sはデータベース（%(about_me)s）にあります。
# 17 of 55
# Say something -> 何か言って
# 18 of 55
# Congratulations, you are now a registered user! -> おめでとう、あなたは登録ユーザーになりました！
# 19 of 55
# Check your email for the instructions to reset your password -> 電子メールでパスワードをリセットする手順を確認してください
# 20 of 55
# Your password has been reset -> あなたのパスワードはリセットされました
# 21 of 55
# Invalid username or password -> ユーザー名かパスワードが無効
# 22 of 55
# Your post is alive! -> あなたの投稿は生きている！
# 23 of 55
# Your changes have been saved %(username)s. -> 変更内容が保存されました %(username)s。
# 24 of 55
# User %(username)s isn't in our database. -> ユーザー%(username)sは私たちのデータベースにありません。
# 25 of 55
# You cannot follow yourself! -> あなたは自分自身に従うことはできません！
# 26 of 55
# You are following %(username)s! -> あなたは%(username)sをフォローしています！
# 27 of 55
# User %(username)s is not in our database -> ユーザー%(username)sは私たちのデータベースにありません
# 28 of 55
# You cannot unfollow yourself! -> あなたは自分自身をアンフォローすることはできません！
# 29 of 55
# You are not following %(username)s. -> あなたは%(username)sをフォローしていません。
# 30 of 55
# File Not Found -> ファイルが見つかりません
# 31 of 55
# Back -> バック
# 32 of 55
# %(username)s said %(when)s -> %(username)s said %(when)s
# 33 of 55
# Welcome to Devasoft -> Devasoftへようこそ
# 34 of 55
# Home -> ホーム
# 35 of 55
# Explore -> 探検する
# 36 of 55
# Login -> ログイン
# 37 of 55
# Profile -> プロフィール
# 38 of 55
# Logout -> ログアウト
# 39 of 55
# Edit Profile -> プロファイル編集
# 40 of 55
# Hi -> こんにちは
# 41 of 55
# Newer posts -> より新しいポスト
# 42 of 55
# Older posts -> 古い投稿
# 43 of 55
# New User? -> 新しいユーザー？
# 44 of 55
# Click to Register! -> クリックして登録！
# 45 of 55
# Forgot Your Password? -> パスワードをお忘れですか？
# 46 of 55
# Click to Reset It -> クリックしてリセットする
# 47 of 55
# Reset Your Password -> あなたのパスワードをリセット
# 48 of 55
# Reset Password -> パスワードを再設定する
# 49 of 55
# User -> ユーザー
# 50 of 55
# Last seen on -> 最後に見た
# 51 of 55
# followers -> フォロワー
# 52 of 55
# following -> 以下
# 53 of 55
# Edit your profile -> あなたのプロフィールを編集する
# 54 of 55
# Follow -> フォローする
# 55 of 55
# Unfollow -> アンフォロー
# 1 of 5 ko /home/zetdg/Devasoft/devablog/app/translations/ko/LC_MESSAGES/messages.po
#
# Now Translating...
# 1 of 55
# 2 of 55
# Please log in to access this page. -> 이 페이지에 액세스하려면 로그인하십시오.
# 3 of 55
# Username -> 사용자 이름
# 4 of 55
# Password -> 암호
# 5 of 55
# Remember Me -> 날 기억해
# 6 of 55
# Sign In -> 로그인
# 7 of 55
# Email -> 이메일
# 8 of 55
# Repeat Password -> 비밀번호 반복
# 9 of 55
# Register -> 레지스터
# 10 of 55
# Please use a different username. -> 다른 사용자 이름을 사용하십시오.
# 11 of 55
# Please use a different email address. -> 다른 이메일 주소를 사용하십시오.
# 12 of 55
# Request Password Reset -> 비밀번호 재설정 요청
# 13 of 55
# About me -> 나에 대해서
# 14 of 55
# Submit -> 제출
# 15 of 55
# The original name is %(username)s. -> 원래 이름은 %(username)s입니다.
# 16 of 55
# Choose another name, %(username)s is in the database (%(about_me)s). -> 다른 이름을 선택하십시오. %(username)s는 데이터베이스 (%(about_me)s)에 있습니다.
# 17 of 55
# Say something -> 뭐라고 말해봐.
# 18 of 55
# Congratulations, you are now a registered user! -> 축하합니다. 등록 된 사용자입니다!
# 19 of 55
# Check your email for the instructions to reset your password -> 이메일 재설정을위한 지침을 확인하십시오.
# 20 of 55
# Your password has been reset -> 당신의 비밀번호가 초기화되었습니다
# 21 of 55
# Invalid username or password -> 잘못된 사용자 이름 또는 비밀번호
# 22 of 55
# Your post is alive! -> 귀하의 게시물이 살아 있습니다!
# 23 of 55
# Your changes have been saved %(username)s. -> 변경 사항은 %(username)s에 저장되었습니다.
# 24 of 55
# User %(username)s isn't in our database. -> 사용자 %(username)s이 (가) 우리 데이터베이스에 없습니다.
# 25 of 55
# You cannot follow yourself! -> 너 자신을 따라갈 수 없어!
# 26 of 55
# You are following %(username)s! -> %(username)s 님을 팔로우하고 있습니다.
# 27 of 55
# User %(username)s is not in our database -> 사용자 %(username)s은 (는) 데이터베이스에 없습니다.
# 28 of 55
# You cannot unfollow yourself! -> 당신은 자신을 unfollow 수 없습니다!
# 29 of 55
# You are not following %(username)s. -> %(username)s을 (를) 따르지 않습니다.
# 30 of 55
# File Not Found -> 파일을 찾을 수 없음
# 31 of 55
# Back -> 뒤로
# 32 of 55
# %(username)s said %(when)s -> %(username)s said %(when)s
# 33 of 55
# Welcome to Devasoft -> Devasoft에 오신 것을 환영합니다.
# 34 of 55
# Home -> 집
# 35 of 55
# Explore -> 탐색
# 36 of 55
# Login -> 로그인
# 37 of 55
# Profile -> 윤곽
# 38 of 55
# Logout -> 로그 아웃
# 39 of 55
# Edit Profile -> 프로필 수정
# 40 of 55
# Hi -> 안녕
# 41 of 55
# Newer posts -> 최근 게시물
# 42 of 55
# Older posts -> 이전 게시물
# 43 of 55
# New User? -> 새로운 사용자?
# 44 of 55
# Click to Register! -> 클릭하여 등록하십시오!
# 45 of 55
# Forgot Your Password? -> 비밀번호를 잊어 버렸습니까?
# 46 of 55
# Click to Reset It -> 재설정하려면 클릭하십시오.
# 47 of 55
# Reset Your Password -> 비밀번호를 재설정
# 48 of 55
# Reset Password -> 암호를 재설정
# 49 of 55
# User -> 사용자
# 50 of 55
# Last seen on -> 마지막으로 본 시간
# 51 of 55
# followers -> 추종자
# 52 of 55
# following -> 수행원
# 53 of 55
# Edit your profile -> 프로필 수정
# 54 of 55
# Follow -> 따르다
# 55 of 55
# Unfollow -> 팔로우 해제
# 2 of 5 fr /home/zetdg/Devasoft/devablog/app/translations/fr/LC_MESSAGES/messages.po
#
# Now Translating...
# 1 of 55
# 2 of 55
# Please log in to access this page. -> Veuillez vous connecter pour accéder à cette page.
# 3 of 55
# Username -> Nom d'utilisateur
# 4 of 55
# Password -> Mot de passe
# 5 of 55
# Remember Me -> Remember Me
# 6 of 55
# Sign In -> Se connecter
# 7 of 55
# Email -> Email
# 8 of 55
# Repeat Password -> Répéter le mot de passe
# 9 of 55
# Register -> registre
# 10 of 55
# Please use a different username. -> Veuillez utiliser un nom d'utilisateur différent.
# 11 of 55
# Please use a different email address. -> Veuillez utiliser une adresse e-mail différente
# 12 of 55
# Request Password Reset -> Demander le mot de passe
# 13 of 55
# About me -> À propos de moi
# 14 of 55
# Submit -> Soumettre
# 15 of 55
# The original name is %(username)s. -> Le nom d'origine est %(username)s.
# 16 of 55
# Choose another name, %(username)s is in the database (%(about_me)s). -> Choisissez un autre nom, %(username)s dans la base de données (%(about_me)s).
# 17 of 55
# Say something -> Dis quelquechose
# 18 of 55
# Congratulations, you are now a registered user! -> Félicitations, vous êtes maintenant un utilisateur enregistré!
# 19 of 55
# Check your email for the instructions to reset your password -> Vérifiez votre email pour les instructions pour réinitialiser votre mot de passe
# 20 of 55
# Your password has been reset -> votre mot de passe a été réinitialisé
# 21 of 55
# Invalid username or password -> Nom d'utilisateur ou mot de passe invalide
# 22 of 55
# Your post is alive! -> Votre message est vivant!
# 23 of 55
# Your changes have been saved %(username)s. -> Vos changements ont été enregistrés %(username)s.
# 24 of 55
# User %(username)s isn't in our database. -> L'utilisateur %(username)s n'est pas dans notre base de données.
# 25 of 55
# You cannot follow yourself! -> Vous ne pouvez pas vous suivre!
# 26 of 55
# You are following %(username)s! -> Vous êtes en train de suivre %(username)s!
# 27 of 55
# User %(username)s is not in our database -> L'utilisateur %(username)s n'est pas dans notre base de données
# 28 of 55
# You cannot unfollow yourself! -> Vous ne pouvez pas vous déconnecter!
# 29 of 55
# You are not following %(username)s. -> Vous ne suivez pas %(username)s.
# 30 of 55
# File Not Found -> Fichier non trouvé
# 31 of 55
# Back -> Arrière
# 32 of 55
# %(username)s said %(when)s -> %(username)s m'a dit %(when)s
# 33 of 55
# Welcome to Devasoft -> Bienvenue à Devasoft
# 34 of 55
# Home -> Accueil
# 35 of 55
# Explore -> Explorer
# 36 of 55
# Login -> S'identifier
# 37 of 55
# Profile -> Profil
# 38 of 55
# Logout -> Connectez - Out
# 39 of 55
# Edit Profile -> Editer le profil
# 40 of 55
# Hi -> salut
# 41 of 55
# Newer posts -> messages plus récents
# 42 of 55
# Older posts -> Articles plus anciens
# 43 of 55
# New User? -> Nouvel utilisateur?
# 44 of 55
# Click to Register! -> Cliquez pour vous inscrire!
# 45 of 55
# Forgot Your Password? -> Mot de passe oublié?
# 46 of 55
# Click to Reset It -> Cliquez pour réinitialiser
# 47 of 55
# Reset Your Password -> Réinitialisez votre mot de passe
# 48 of 55
# Reset Password -> réinitialiser le mot de passe
# 49 of 55
# User -> Utilisateur
# 50 of 55
# Last seen on -> Vu la dernière fois sur
# 51 of 55
# followers -> suiveurs
# 52 of 55
# following -> Suivant
# 53 of 55
# Edit your profile -> Modifier votre profil
# 54 of 55
# Follow -> Suivre
# 55 of 55
# Unfollow -> Ne pas
# 3 of 5 es /home/zetdg/Devasoft/devablog/app/translations/es/LC_MESSAGES/messages.po
#
# Now Translating...
# 1 of 55
# 2 of 55
# Please log in to access this page. -> Por favor inicie sesión para acceder a esta página.
# 3 of 55
# Username -> Nombre de usuario
# 4 of 55
# Password -> Contraseña
# 5 of 55
# Remember Me -> Recuérdame
# 6 of 55
# Sign In -> Registrarse
# 7 of 55
# Email -> Email
# 8 of 55
# Repeat Password -> Repite la contraseña
# 9 of 55
# Register -> Registro
# 10 of 55
# Please use a different username. -> Por favor use un nombre de usuario diferente.
# 11 of 55
# Please use a different email address. -> Por favor utilice una dirección de correo electrónico diferente.
# 12 of 55
# Request Password Reset -> Petición para la recuperación de contraseña
# 13 of 55
# About me -> Sobre mi
# 14 of 55
# Submit -> Enviar
# 15 of 55
# The original name is %(username)s. -> El nombre original es %(username)s.
# 16 of 55
# Choose another name, %(username)s is in the database (%(about_me)s). -> Elija otro nombre, %(username)s está en la base de datos (%(about_me)s).
# 17 of 55
# Say something -> Di algo
# 18 of 55
# Congratulations, you are now a registered user! -> ¡Felicitaciones, ahora eres un usuario registrado!
# 19 of 55
# Check your email for the instructions to reset your password -> Consulte su correo electrónico para obtener las instrucciones para restablecer su contraseña
# 20 of 55
# Your password has been reset -> Tu contraseña ha sido restablecida
# 21 of 55
# Invalid username or password -> usuario o contraseña invalido
# 22 of 55
# Your post is alive! -> ¡Tu publicación está viva!
# 23 of 55
# Your changes have been saved %(username)s. -> Se han guardado los cambios %(username)s.
# 24 of 55
# User %(username)s isn't in our database. -> El usuario %(username)s no está en nuestra base de datos.
# 25 of 55
# You cannot follow yourself! -> ¡No puedes seguirte!
# 26 of 55
# You are following %(username)s! -> Estas siguiendo %(username)s!
# 27 of 55
# User %(username)s is not in our database -> Usuario %(username)s no está en nuestra base de datos
# 28 of 55
# You cannot unfollow yourself! -> ¡No puedes dejar de seguir!
# 29 of 55
# You are not following %(username)s. -> No estás siguiendo %(username)s.
# 30 of 55
# File Not Found -> Archivo no encontrado
# 31 of 55
# Back -> Espalda
# 32 of 55
# %(username)s said %(when)s -> %(username)s dijo %(when)s
# 33 of 55
# Welcome to Devasoft -> Bienvenido a Devasoft
# 34 of 55
# Home -> Casa
# 35 of 55
# Explore -> Explorar
# 36 of 55
# Login -> Iniciar sesión
# 37 of 55
# Profile -> Perfil
# 38 of 55
# Logout -> Cerrar sesión
# 39 of 55
# Edit Profile -> Editar perfil
# 40 of 55
# Hi -> Hola
# 41 of 55
# Newer posts -> las publicaciones más nuevas
# 42 of 55
# Older posts -> Publicaciones anteriores
# 43 of 55
# New User? -> ¿Nuevo usuario?
# 44 of 55
# Click to Register! -> Haga clic para registrarse!
# 45 of 55
# Forgot Your Password? -> ¿Olvidaste tu contraseña?
# 46 of 55
# Click to Reset It -> Haga clic para restablecerlo
# 47 of 55
# Reset Your Password -> Restablecer su contraseña
# 48 of 55
# Reset Password -> Restablecer la contraseña
# 49 of 55
# User -> Usuario
# 50 of 55
# Last seen on -> Visto por última vez en
# 51 of 55
# followers -> seguidores
# 52 of 55
# following -> siguiendo
# 53 of 55
# Edit your profile -> Edite su perfil
# 54 of 55
# Follow -> Seguir
# 55 of 55
# Unfollow -> Dejar de seguir
# 4 of 5 de /home/zetdg/Devasoft/devablog/app/translations/de/LC_MESSAGES/messages.po
#
# Now Translating...
# 1 of 55
# 2 of 55
# Please log in to access this page. -> Bitte melden Sie sich an, um auf diese Seite zuzugreifen.
# 3 of 55
# Username -> Nutzername
# 4 of 55
# Password -> Passwort
# 5 of 55
# Remember Me -> Erinnere dich an mich
# 6 of 55
# Sign In -> Anmelden
# 7 of 55
# Email -> Email
# 8 of 55
# Repeat Password -> Passwort wiederholen
# 9 of 55
# Register -> Registrieren
# 10 of 55
# Please use a different username. -> Bitte verwenden Sie einen anderen Benutzernamen.
# 11 of 55
# Please use a different email address. -> Bitte verwenden Sie eine andere E-Mail-Adresse.
# 12 of 55
# Request Password Reset -> Fordere Passwort-Reset an
# 13 of 55
# About me -> Über mich
# 14 of 55
# Submit -> einreichen
# 15 of 55
# The original name is %(username)s. -> Der ursprüngliche Name ist %(username)s.
# 16 of 55
# Choose another name, %(username)s is in the database (%(about_me)s). -> Wählen Sie einen anderen Namen, %(username)s ist in der Datenbank (%(about_me)s).
# 17 of 55
# Say something -> Sag etwas
# 18 of 55
# Congratulations, you are now a registered user! -> Herzlichen Glückwunsch, Sie sind jetzt ein registrierter Benutzer!
# 19 of 55
# Check your email for the instructions to reset your password -> Überprüfen Sie Ihre E-Mail auf die Anweisungen zum Zurücksetzen Ihres Passworts
# 20 of 55
# Your password has been reset -> Dein Passwort wurde zurück gesetzt
# 21 of 55
# Invalid username or password -> ungültiger Benutzername oder Passwort
# 22 of 55
# Your post is alive! -> Dein Beitrag lebt!
# 23 of 55
# Your changes have been saved %(username)s. -> Ihre Änderungen wurden gespeichert %(username)s.
# 24 of 55
# User %(username)s isn't in our database. -> Benutzer %(username)s ist nicht in unserer Datenbank.
# 25 of 55
# You cannot follow yourself! -> Du kannst dir selbst nicht folgen!
# 26 of 55
# You are following %(username)s! -> Du folgst %(username)s!
# 27 of 55
# User %(username)s is not in our database -> Benutzer %(username)s ist nicht in unserer Datenbank
# 28 of 55
# You cannot unfollow yourself! -> Du kannst dich nicht selbständig machen!
# 29 of 55
# You are not following %(username)s. -> Sie folgen nicht %(username)s.
# 30 of 55
# File Not Found -> Datei nicht gefunden
# 31 of 55
# Back -> Zurück
# 32 of 55
# %(username)s said %(when)s -> %(username)s sagte %(when)s
# 33 of 55
# Welcome to Devasoft -> Willkommen bei Devasoft
# 34 of 55
# Home -> Zuhause
# 35 of 55
# Explore -> Erkunden
# 36 of 55
# Login -> Anmeldung
# 37 of 55
# Profile -> Profil
# 38 of 55
# Logout -> Ausloggen
# 39 of 55
# Edit Profile -> Profil bearbeiten
# 40 of 55
# Hi -> Hallo
# 41 of 55
# Newer posts -> Neuere Beiträge
# 42 of 55
# Older posts -> ältere Beiträge
# 43 of 55
# New User? -> Neuer Benutzer?
# 44 of 55
# Click to Register! -> Klicken Sie, um sich zu registrieren!
# 45 of 55
# Forgot Your Password? -> Haben Sie Ihr Passwort vergessen?
# 46 of 55
# Click to Reset It -> Klicken Sie, um es zurückzusetzen
# 47 of 55
# Reset Your Password -> Setze dein Passwort zurück
# 48 of 55
# Reset Password -> Passwort zurücksetzen
# 49 of 55
# User -> Benutzer
# 50 of 55
# Last seen on -> Zuletzt gesehen am
# 51 of 55
# followers -> Anhänger
# 52 of 55
# following -> Folgendes
# 53 of 55
# Edit your profile -> bearbeite dein Profil
# 54 of 55
# Follow -> Folgen
# 55 of 55
# Unfollow -> Nicht folgen
